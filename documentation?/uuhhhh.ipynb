# %% [markdown]
# ### twelve billion datapoints

# %% [markdown]
# Any of the values that use text or non-integer based information are effectively useless for machine learning, as the text-based data is too unique to be turned into meaningful data.
